# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def swap(s1, s2):
    return (s2[:2]+s1[2:]+" "+s1[:2]+s2[2:])

print("Input: ")
s1 = input()
s2 = input()

print("\nOutput: ")
print(swap(s1, s2))
# Out:
# Input:
# code
# debug
#
# Output:
# dede cobug
