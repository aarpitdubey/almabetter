# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def pick_color(color_list):
    return (color_list[0]+" "+color_list[len(color_list) - 1])

print("Input: \n")
color_list = ["Red", "Green", "White", "Black"]
print(color_list)

print("\nOutput: \n")
print(pick_color(color_list))
# Out:
# Input:
#
# ['Red', 'Green', 'White', 'Black']
#
# Output:
#
# Red Black
